# %%
import pandas as pd
import numpy as np
import strsimpy
print('setup done!')
# Out:
# setup done!

# %%
df = pd.read_json('./data.json')
arr = df.to_numpy()

levenshtein  = strsimpy.NormalizedLevenshtein()

def levenshtein_score(x,y):
    if (x=='unknown' or y =='unknown'):
        return 1
    return 1 - levenshtein.distance(x,y)

def difference_score(x,y):
    if (x=='unknown' or y =='unknown'):
        return 1
    return 1 if x==y else 0

# %%
def clust_filter(arr):
    flag = [False]*len(arr)
    cluster  = [] 
    for i in range(0,len(arr)-1):
        if (flag[i]==False):
            for j in range(i + 1, len(arr)):
                if (flag[j]==False):
                    name = levenshtein_score(arr[i][0],arr[j][0])
                    cpu = difference_score(arr[i][2],arr[j][2])
                    ram = difference_score(arr[i][5],arr[j][5])
                    rom = difference_score(arr[i][6],arr[j][6])
                    color = difference_score(arr[i][10],arr[j][10])
                    score = 0.5 * name + 0.05 * cpu + 0.2 * ram + 0.2 * rom + 0.05 * color
                    if (score > 0.95):
                        flag[j] = True
            cluster.append(arr[i])
    return cluster

# %%
cluster = clust_filter(arr)
print(len(cluster))
new_df = pd.DataFrame(cluster)[[0,2,5,6,10]]
print(new_df.sort_values(by=[0,5,6]))
# Out:
# 404
#                        0        2        5        6               10
# 251        APPLE WATCH SE  unknown  unknown  unknown            PINK
# 252        APPLE WATCH SE  unknown  unknown  unknown          PURPLE
# 253        APPLE WATCH SE  unknown  unknown  unknown           WHITE
# 254        APPLE WATCH SE  unknown  unknown  unknown            GOLD
# 259        APPLE WATCH SE  unknown  unknown  unknown    YELLOW/WHITE
# 260        APPLE WATCH SE  unknown  unknown  unknown           BLACK
# 261        APPLE WATCH SE  unknown  unknown  unknown            GRAY
# 262        APPLE WATCH SE  unknown  unknown  unknown      GRAY/BLACK
# 263        APPLE WATCH SE  unknown  unknown  unknown           GREEN
# 264        APPLE WATCH SE  unknown  unknown  unknown            BLUE
# 265        APPLE WATCH SE  unknown  unknown  unknown             RED
# 266        APPLE WATCH SE  unknown  unknown  unknown           BROWN
# 267        APPLE WATCH SE  unknown  unknown  unknown          YELLOW
# 273        APPLE WATCH SE  unknown  unknown  unknown       DARK GRAY
# 255  APPLE WATCH SERIES 6  unknown  unknown  unknown           WHITE
# 256  APPLE WATCH SERIES 6  unknown  unknown  unknown            GOLD
# 257  APPLE WATCH SERIES 6  unknown  unknown  unknown           GREEN
# 258  APPLE WATCH SERIES 6  unknown  unknown  unknown           BLACK
# 268  APPLE WATCH SERIES 6  unknown  unknown  unknown            GRAY
# 269  APPLE WATCH SERIES 6  unknown  unknown  unknown            PINK
# 270  APPLE WATCH SERIES 6  unknown  unknown  unknown             RED
# 271  APPLE WATCH SERIES 6  unknown  unknown  unknown          SILVER
# 272  APPLE WATCH SERIES 6  unknown  unknown  unknown            BLUE
# 322             IPAD 10.2      A13        3      256         unknown
# 314             IPAD 10.2      A13        3       64         unknown
# 328             IPAD 2018  unknown  unknown  unknown         unknown
# 329                IPAD 4  unknown  unknown  unknown         unknown
# 330                IPAD 9  unknown  unknown  unknown         unknown
# 321            IPAD AIR 1      A14  unknown      256         unknown
# 316            IPAD AIR 1  unknown  unknown       64         unknown
# 324            IPAD AIR 2  unknown  unknown  unknown         unknown
# 337            IPAD AIR 4      A14        4      256         unknown
# 341            IPAD AIR 4      A14        4       64         unknown
# 323         IPAD AIR 5 M1       M1        8      256         unknown
# 318         IPAD AIR 5 M1       M1        8       64         unknown
# 331            IPAD GEN 5  unknown  unknown  unknown         unknown
# 326            IPAD GEN 6  unknown  unknown  unknown         unknown
# 320           IPAD MINI 6      A15        3      256         unknown
# 315           IPAD MINI 6      A15        3       64         unknown
# 339           IPAD MINI 6      A15        4      256         unknown
# 340           IPAD MINI 6      A15        4       64         unknown
# 332           IPAD PRO 11  unknown  unknown  unknown         unknown
# 325         IPAD PRO 12.9  unknown  unknown  unknown         unknown
# 327          IPAD PRO 9.7  unknown  unknown  unknown         unknown
# 338   IPAD PRO M1 11 INCH       M1        8      128         unknown
# 317   IPAD PRO M1 11 INCH  unknown        8      256         unknown
# 319      IPAD PRO M1 12.9       M1        8      128         unknown
# 68              IPHONE 11      A13        4      128             RED
# 69              IPHONE 11      A13        4      128          PURPLE
# 70              IPHONE 11      A13        4      128           BLACK
# 71              IPHONE 11      A13        4      128           WHITE
# 72              IPHONE 11      A13        4      128            GOLD
# 73              IPHONE 11      A13        4      128           GREEN
# 166             IPHONE 11      A13        4      128       BLUE SKIN
# 76              IPHONE 11      A13        4      256             RED
# 77              IPHONE 11      A13        4      256          PURPLE
# 78              IPHONE 11      A13        4      256           WHITE
# 79              IPHONE 11      A13        4      256           BLACK
# 80              IPHONE 11      A13        4      256       BLUE SKIN
# 379             IPHONE 11      A13        4      256            GOLD
# 380             IPHONE 11      A13        4      256           GREEN
# 42              IPHONE 11      A13        4       64             RED
# 43              IPHONE 11      A13        4       64          PURPLE
# 44              IPHONE 11      A13        4       64        JETBLACK
# 45              IPHONE 11      A13        4       64           WHITE
# 46              IPHONE 11      A13        4       64            GOLD
# 47              IPHONE 11      A13        4       64           GREEN
# 57              IPHONE 11      A13        4       64           BLACK
# 96              IPHONE 11      A13        4       64       BLUE SKIN
# 119         IPHONE 11 PRO      A13        4      256           BLACK
# 120         IPHONE 11 PRO      A13        4      256           WHITE
# 121         IPHONE 11 PRO      A13        4      256      MOSS GREEN
# 122         IPHONE 11 PRO      A13        4      256            GOLD
# 195         IPHONE 11 PRO      A13        4      512          SILVER
# 196         IPHONE 11 PRO      A13        4      512            GOLD
# 48          IPHONE 11 PRO      A13        4       64           BLACK
# 49          IPHONE 11 PRO      A13        4       64      MOSS GREEN
# 50          IPHONE 11 PRO      A13        4       64          SILVER
# 51          IPHONE 11 PRO      A13        4       64            GOLD
# 118         IPHONE 11 PRO      A13        4       64            GRAY
# 310         IPHONE 11 PRO      A13        4       64           WHITE
# 311         IPHONE 11 PRO      A13        4       64           GREEN
# 371         IPHONE 11 PRO  unknown  unknown      256  MIDNIGHT GREEN
# 370         IPHONE 11 PRO  unknown  unknown       64  MIDNIGHT GREEN
# 64      IPHONE 11 PRO MAX      A13        4      256            GRAY
# 65      IPHONE 11 PRO MAX      A13        4      256          SILVER
# 66      IPHONE 11 PRO MAX      A13        4      256      MOSS GREEN
# 67      IPHONE 11 PRO MAX      A13        4      256            GOLD
# 283     IPHONE 11 PRO MAX      A13        4      256           WHITE
# 284     IPHONE 11 PRO MAX      A13        4      256           BLACK
# 285     IPHONE 11 PRO MAX      A13        4      256           GREEN
# 366     IPHONE 11 PRO MAX      A13        4      256  MIDNIGHT GREEN
# 209     IPHONE 11 PRO MAX  unknown        4      512         unknown
# 16      IPHONE 11 PRO MAX      A13        4       64           BLACK
# 17      IPHONE 11 PRO MAX      A13        4       64          SILVER
# 18      IPHONE 11 PRO MAX      A13        4       64      MOSS GREEN
# 19      IPHONE 11 PRO MAX      A13        4       64            GOLD
# 312     IPHONE 11 PRO MAX      A13        4       64           WHITE
# 313     IPHONE 11 PRO MAX      A13        4       64           GREEN
# 402     IPHONE 11 PRO MAX  unknown  unknown       64  MIDNIGHT GREEN
# 403     IPHONE 11 PRO MAX  unknown  unknown       64            GRAY
# 179             IPHONE 12      A14        4      128           BLACK
# 180             IPHONE 12      A14        4      128           GREEN
# 181             IPHONE 12      A14        4      128           WHITE
# 240             IPHONE 12      A14        4      128            BLUE
# 333             IPHONE 12      A15        4      128         unknown
# 354             IPHONE 12      A14        4      128      GREEN MINT
# 355             IPHONE 12      A14        4      128       NAVY BLUE
# 356             IPHONE 12      A14        4      128             RED
# 357             IPHONE 12      A14        4      128          PURPLE
# 197             IPHONE 12      A14        4      256             RED
# 358             IPHONE 12      A14        4      256           BLACK
# 359             IPHONE 12      A14        4      256      GREEN MINT
# 360             IPHONE 12      A14        4      256           WHITE
# 361             IPHONE 12      A14        4      256       NAVY BLUE
# 362             IPHONE 12      A14        4      256          PURPLE
# 0               IPHONE 12      A14        4       64           BLACK
# 1               IPHONE 12      A14        4       64           WHITE
# 2               IPHONE 12      A14        4       64          PURPLE
# 3               IPHONE 12      A14        4       64             RED
# 4               IPHONE 12      A14        4       64           GREEN
# 352             IPHONE 12      A14        4       64      GREEN MINT
# 353             IPHONE 12      A14        4       64       NAVY BLUE
# 106        IPHONE 12 MINI      A14        4      128             RED
# 107        IPHONE 12 MINI      A14        4      128           BLACK
# 108        IPHONE 12 MINI      A14        4      128          PURPLE
# 109        IPHONE 12 MINI      A14        4      128           GREEN
# 110        IPHONE 12 MINI      A14        4      128           WHITE
# 395        IPHONE 12 MINI      A14        4      128      GREEN MINT
# 396        IPHONE 12 MINI      A14        4      128       NAVY BLUE
# 397        IPHONE 12 MINI      A14        4      256      GREEN MINT
# 398        IPHONE 12 MINI      A14        4      256       NAVY BLUE
# 399        IPHONE 12 MINI      A14        4      256           BLACK
# 400        IPHONE 12 MINI      A14        4      256             RED
# 401        IPHONE 12 MINI      A14        4      256           WHITE
# 192        IPHONE 12 MINI      A14        4       64           BLACK
# 193        IPHONE 12 MINI      A14        4       64           GREEN
# 194        IPHONE 12 MINI      A14        4       64           WHITE
# 250        IPHONE 12 MINI      A14        4       64            BLUE
# 392        IPHONE 12 MINI      A14        4       64      GREEN MINT
# 393        IPHONE 12 MINI      A14        4       64       NAVY BLUE
# 394        IPHONE 12 MINI      A14        4       64             RED
# 24          IPHONE 12 PRO      A14        6      128        GRAPHITE
# 25          IPHONE 12 PRO      A14        6      128           GREEN
# 26          IPHONE 12 PRO      A14        6      128           WHITE
# 27          IPHONE 12 PRO      A14        6      128            GOLD
# 374         IPHONE 12 PRO      A14        6      128           BLACK
# 375         IPHONE 12 PRO      A14        6      128       NAVY BLUE
# 97          IPHONE 12 PRO      A14        6      256        GRAPHITE
# 98          IPHONE 12 PRO      A14        6      256           WHITE
# 99          IPHONE 12 PRO      A14        6      256           GREEN
# 100         IPHONE 12 PRO      A14        6      256            GOLD
# 241         IPHONE 12 PRO      A14        6      256            BLUE
# 242         IPHONE 12 PRO      A14        6      256          SILVER
# 243         IPHONE 12 PRO      A14        6      256            GRAY
# 372         IPHONE 12 PRO      A14        6      256           BLACK
# 373         IPHONE 12 PRO      A14        6      256       NAVY BLUE
# 131         IPHONE 12 PRO      A14        6      512        GRAPHITE
# 132         IPHONE 12 PRO      A14        6      512           GREEN
# 133         IPHONE 12 PRO      A14        6      512           WHITE
# 376         IPHONE 12 PRO      A14        6      512           BLACK
# 377         IPHONE 12 PRO      A14        6      512       NAVY BLUE
# 378         IPHONE 12 PRO      A14        6      512            GOLD
# 20      IPHONE 12 PRO MAX      A14        6      128        GRAPHITE
# 21      IPHONE 12 PRO MAX      A14        6      128           GREEN
# 22      IPHONE 12 PRO MAX      A14        6      128           WHITE
# 23      IPHONE 12 PRO MAX      A14        6      128            GOLD
# 363     IPHONE 12 PRO MAX      A14        6      128            GRAY
# 364     IPHONE 12 PRO MAX      A14        6      128       NAVY BLUE
# 387     IPHONE 12 PRO MAX      A14        6      128           BLACK
# 102     IPHONE 12 PRO MAX      A14        6      256        GRAPHITE
# 103     IPHONE 12 PRO MAX      A14        6      256           GREEN
# 104     IPHONE 12 PRO MAX      A14        6      256           WHITE
# 105     IPHONE 12 PRO MAX      A14        6      256            GOLD
# 244     IPHONE 12 PRO MAX      A14        6      256            GRAY
# 245     IPHONE 12 PRO MAX      A14        6      256            BLUE
# 246     IPHONE 12 PRO MAX      A14        6      256          SILVER
# 365     IPHONE 12 PRO MAX      A14        6      256       NAVY BLUE
# 388     IPHONE 12 PRO MAX      A14        6      256           BLACK
# 182     IPHONE 12 PRO MAX      A14        6      512           GREEN
# 183     IPHONE 12 PRO MAX      A14        6      512        GRAPHITE
# 184     IPHONE 12 PRO MAX      A14        6      512            GOLD
# 389     IPHONE 12 PRO MAX      A14        6      512           BLACK
# 390     IPHONE 12 PRO MAX      A14        6      512           WHITE
# 391     IPHONE 12 PRO MAX      A14        6      512       NAVY BLUE
# 10              IPHONE 13      A15        4      128           GREEN
# 11              IPHONE 13      A15        4      128           BLACK
# 12              IPHONE 13      A15        4      128             RED
# 13              IPHONE 13      A15        4      128           WHITE
# 14              IPHONE 13      A15        4      128            BLUE
# 15              IPHONE 13      A15        4      128            PINK
# 345             IPHONE 13      A15        4      128        SEA BLUE
# 86              IPHONE 13      A15        4      256           BLACK
# 87              IPHONE 13      A15        4      256            BLUE
# 88              IPHONE 13      A15        4      256           WHITE
# 89              IPHONE 13      A15        4      256           GREEN
# 90              IPHONE 13      A15        4      256             RED
# 91              IPHONE 13      A15        4      256            PINK
# 208             IPHONE 13  unknown        4      512         unknown
# 346             IPHONE 13      A15        6      256           GREEN
# 347             IPHONE 13      A15        6      256        SEA BLUE
# 348             IPHONE 13      A15        6      256            PINK
# 349             IPHONE 13      A15        6      256           BLACK
# 350             IPHONE 13      A15        6      256             RED
# 351             IPHONE 13      A15        6      256           WHITE
# 126        IPHONE 13 MINI      A15        4      128           WHITE
# 127        IPHONE 13 MINI      A15        4      128            PINK
# 128        IPHONE 13 MINI      A15        4      128           BLACK
# 129        IPHONE 13 MINI      A15        4      128             RED
# 130        IPHONE 13 MINI      A15        4      128            BLUE
# 249        IPHONE 13 MINI      A15        4      128           GREEN
# 367        IPHONE 13 MINI      A15        4      128        SEA BLUE
# 134        IPHONE 13 MINI      A15        4      256            PINK
# 135        IPHONE 13 MINI      A15        4      256           WHITE
# 136        IPHONE 13 MINI      A15        4      256             RED
# 137        IPHONE 13 MINI      A15        4      256            BLUE
# 138        IPHONE 13 MINI      A15        4      256           BLACK
# 248        IPHONE 13 MINI      A15        4      256           GREEN
# 368        IPHONE 13 MINI      A15        4      256        SEA BLUE
# 139        IPHONE 13 MINI      A15        4      512             RED
# 140        IPHONE 13 MINI      A15        4      512           BLACK
# 141        IPHONE 13 MINI      A15        4      512           WHITE
# 142        IPHONE 13 MINI      A15        4      512            BLUE
# 143        IPHONE 13 MINI      A15        4      512            PINK
# 247        IPHONE 13 MINI      A15        4      512           GREEN
# 369        IPHONE 13 MINI      A15        4      512        SEA BLUE
# 334        IPHONE 13 MINI  unknown  unknown  unknown          YELLOW
# 336        IPHONE 13 MINI  unknown  unknown  unknown          ORANGE
# 147         IPHONE 13 PRO      A15        6        1            BLUE
# 148         IPHONE 13 PRO      A15        6        1        GRAPHITE
# 149         IPHONE 13 PRO      A15        6        1           WHITE
# 150         IPHONE 13 PRO      A15        6        1            GOLD
# 234         IPHONE 13 PRO      A15        6        1   GOLDEN BRONZE
# 235         IPHONE 13 PRO      A15        6        1            GRAY
# 236         IPHONE 13 PRO      A15        6        1          SILVER
# 342         IPHONE 13 PRO      A15        6        1           GREEN
# 5           IPHONE 13 PRO      A15        6      128          YELLOW
# 6           IPHONE 13 PRO      A15        6      128            BLUE
# 7           IPHONE 13 PRO      A15        6      128        GRAPHITE
# 8           IPHONE 13 PRO      A15        6      128           GREEN
# 9           IPHONE 13 PRO      A15        6      128           WHITE
# 101         IPHONE 13 PRO      A15        6      128            GOLD
# 219         IPHONE 13 PRO      A15        6      128            GRAY
# 220         IPHONE 13 PRO      A15        6      128          SILVER
# 144         IPHONE 13 PRO      A15        6      256        GRAPHITE
# 145         IPHONE 13 PRO      A15        6      256           WHITE
# 146         IPHONE 13 PRO      A15        6      256            BLUE
# 227         IPHONE 13 PRO      A15        6      256           GREEN
# 228         IPHONE 13 PRO      A15        6      256          SILVER
# 229         IPHONE 13 PRO      A15        6      256            GRAY
# 230         IPHONE 13 PRO      A15        6      256            GOLD
# 206         IPHONE 13 PRO      A15        6      512         unknown
# 155     IPHONE 13 PRO MAX      A15        6        1        GRAPHITE
# 156     IPHONE 13 PRO MAX      A15        6        1            BLUE
# 157     IPHONE 13 PRO MAX      A15        6        1            GOLD
# 158     IPHONE 13 PRO MAX      A15        6        1           WHITE
# 237     IPHONE 13 PRO MAX      A15        6        1   GOLDEN BRONZE
# 238     IPHONE 13 PRO MAX      A15        6        1          SILVER
# 239     IPHONE 13 PRO MAX      A15        6        1            GRAY
# 344     IPHONE 13 PRO MAX      A15        6        1           GREEN
# 52      IPHONE 13 PRO MAX      A15        6      128            GOLD
# 53      IPHONE 13 PRO MAX      A15        6      128        GRAPHITE
# 54      IPHONE 13 PRO MAX      A15        6      128            BLUE
# 55      IPHONE 13 PRO MAX      A15        6      128           WHITE
# 56      IPHONE 13 PRO MAX      A15        6      128           GREEN
# 221     IPHONE 13 PRO MAX      A15        6      128            GRAY
# 222     IPHONE 13 PRO MAX      A15        6      128          SILVER
# 81      IPHONE 13 PRO MAX      A15        6      256            GOLD
# 82      IPHONE 13 PRO MAX      A15        6      256           WHITE
# 83      IPHONE 13 PRO MAX      A15        6      256        GRAPHITE
# 84      IPHONE 13 PRO MAX      A15        6      256            BLUE
# 85      IPHONE 13 PRO MAX      A15        6      256           GREEN
# 223     IPHONE 13 PRO MAX      A15        6      256            GRAY
# 224     IPHONE 13 PRO MAX      A15        6      256   GOLDEN BRONZE
# 225     IPHONE 13 PRO MAX      A15        6      256          SILVER
# 151     IPHONE 13 PRO MAX      A15        6      512           WHITE
# 152     IPHONE 13 PRO MAX      A15        6      512        GRAPHITE
# 153     IPHONE 13 PRO MAX      A15        6      512            BLUE
# 154     IPHONE 13 PRO MAX      A15        6      512            GOLD
# 231     IPHONE 13 PRO MAX      A15        6      512     BRONZE GOLD
# 232     IPHONE 13 PRO MAX      A15        6      512          SILVER
# 233     IPHONE 13 PRO MAX      A15        6      512            GRAY
# 343     IPHONE 13 PRO MAX      A15        6      512           GREEN
# 280             IPHONE 5S       A7        1       16           WHITE
# 281             IPHONE 5S       A7        1       16            GOLD
# 282             IPHONE 5S       A7        1       16            GRAY
# 289             IPHONE 5S       A9        2       16           WHITE
# 290             IPHONE 5S       A9        2       16            GRAY
# 291             IPHONE 5S       A9        2       16            PINK
# 292             IPHONE 5S       A9        2       16            GOLD
# 276             IPHONE 5S       A9        2       32           WHITE
# 277             IPHONE 5S       A9        2       32            GRAY
# 278             IPHONE 5S       A9        2       32            PINK
# 279             IPHONE 5S       A9        2       32            GOLD
# 335             IPHONE 5S  unknown  unknown  unknown          YELLOW
# 218              IPHONE 6  unknown        1       16         unknown
# 217              IPHONE 6  unknown        1       32         unknown
# 216              IPHONE 6  unknown        1       64         unknown
# 215             IPHONE 6S  unknown        2       16         unknown
# 185             IPHONE 6S       A9        2       32            GOLD
# 169             IPHONE 6S       A9        2       64            GRAY
# 170             IPHONE 6S       A9        2       64            GOLD
# 274             IPHONE 6S       A9        2       64            PINK
# 275             IPHONE 6S       A9        2       64           WHITE
# 187        IPHONE 6S PLUS       A9        2      128            GRAY
# 214        IPHONE 6S PLUS  unknown        2       16         unknown
# 212        IPHONE 6S PLUS  unknown        2       32         unknown
# 186        IPHONE 6S PLUS       A9        2       64            PINK
# 286        IPHONE 6S PLUS       A9        2       64           WHITE
# 287        IPHONE 6S PLUS       A9        2       64            GOLD
# 288        IPHONE 6S PLUS       A9        2       64            GRAY
# 213              IPHONE 7  unknown        2      128         unknown
# 171              IPHONE 7      A10        2       32           BLACK
# 172              IPHONE 7      A10        2       32          SILVER
# 173              IPHONE 7      A10        2       32       ROSE GOLD
# 294              IPHONE 7      A10        2       32            PINK
# 295              IPHONE 7      A10        2       32           WHITE
# 296              IPHONE 7      A10        2       32            GOLD
# 159         IPHONE 7 PLUS      A10        3      128           BLACK
# 160         IPHONE 7 PLUS      A10        3      128            GOLD
# 161         IPHONE 7 PLUS      A10        3      128           WHITE
# 162         IPHONE 7 PLUS      A10        3      128            PINK
# 163         IPHONE 7 PLUS      A10        3      128        JETBLACK
# 164         IPHONE 7 PLUS      A10        3      128             RED
# 92          IPHONE 7 PLUS      A10        3       32            PINK
# 93          IPHONE 7 PLUS      A10        3       32           BLACK
# 94          IPHONE 7 PLUS      A10        3       32          SILVER
# 95          IPHONE 7 PLUS      A10        3       32            GOLD
# 293         IPHONE 7 PLUS      A10        3       32           WHITE
# 211              IPHONE 8  unknown        2      256         unknown
# 35               IPHONE 8      A11        2       64            GRAY
# 36               IPHONE 8      A11        2       64          SILVER
# 37               IPHONE 8      A11        2       64            GOLD
# 38               IPHONE 8      A11        2       64             RED
# 297              IPHONE 8      A11        2       64           BLACK
# 298              IPHONE 8      A11        2       64           WHITE
# 383         IPHONE 8 PLUS      A11        2      256           BLACK
# 384         IPHONE 8 PLUS      A11        2      256          SILVER
# 385         IPHONE 8 PLUS      A11        2      256             RED
# 386         IPHONE 8 PLUS      A11        2      256            GOLD
# 175         IPHONE 8 PLUS      A11        3      256            GRAY
# 176         IPHONE 8 PLUS      A11        3      256          SILVER
# 177         IPHONE 8 PLUS      A11        3      256            GOLD
# 178         IPHONE 8 PLUS      A11        3      256             RED
# 299         IPHONE 8 PLUS      A11        3      256           WHITE
# 300         IPHONE 8 PLUS      A11        3      256           BLACK
# 31          IPHONE 8 PLUS      A11        3       64            GRAY
# 32          IPHONE 8 PLUS      A11        3       64          SILVER
# 33          IPHONE 8 PLUS      A11        3       64            GOLD
# 34          IPHONE 8 PLUS      A11        3       64             RED
# 306         IPHONE 8 PLUS      A11        3       64           WHITE
# 307         IPHONE 8 PLUS      A11        3       64           BLACK
# 204             IPHONE SE      A15        3      128         unknown
# 205             IPHONE SE      A15        3       64         unknown
# 207        IPHONE SE 2020      A13        3       64         unknown
# 201        IPHONE SE 2022      A15        3      128             RED
# 202        IPHONE SE 2022      A15        3      128           WHITE
# 203        IPHONE SE 2022      A15        3      128           BLACK
# 198        IPHONE SE 2022      A15        3       64             RED
# 199        IPHONE SE 2022      A15        3       64           WHITE
# 200        IPHONE SE 2022      A15        3       64           BLACK
# 189              IPHONE X      A11        3      256            GRAY
# 190              IPHONE X      A11        3      256          SILVER
# 302              IPHONE X      A11        3      256           BLACK
# 303              IPHONE X      A11        3      256           WHITE
# 74               IPHONE X      A11        3       64            GRAY
# 75               IPHONE X      A11        3       64          SILVER
# 174              IPHONE X      A11        3       64           BLACK
# 301              IPHONE X      A11        3       64           WHITE
# 111             IPHONE XR      A12        3      128             RED
# 112             IPHONE XR      A12        3      128           BLACK
# 113             IPHONE XR      A12        3      128            BLUE
# 114             IPHONE XR      A12        3      128           WHITE
# 115             IPHONE XR      A12        3      128            GOLD
# 116             IPHONE XR      A12        3      128          ORANGE
# 304             IPHONE XR      A12        3      128           GREEN
# 58              IPHONE XR      A12        3       64           BLACK
# 59              IPHONE XR      A12        3       64            GOLD
# 60              IPHONE XR      A12        3       64           WHITE
# 61              IPHONE XR      A12        3       64             RED
# 62              IPHONE XR      A12        3       64            BLUE
# 63              IPHONE XR      A12        3       64          ORANGE
# 165             IPHONE XR      A12        3       64        SEA BLUE
# 226             IPHONE XR      A12        3       64           GREEN
# 28              IPHONE XS      A12        4      256          SILVER
# 29              IPHONE XS      A12        4      256        JETBLACK
# 30              IPHONE XS      A12        4      256            GOLD
# 117             IPHONE XS      A12        4      256           BLACK
# 188             IPHONE XS      A12        4      256            GRAY
# 305             IPHONE XS      A12        4      256           WHITE
# 210             IPHONE XS  unknown        4       64         unknown
# 123         IPHONE XS MAX      A12        4      256        JETBLACK
# 124         IPHONE XS MAX      A12        4      256          SILVER
# 125         IPHONE XS MAX      A12        4      256            GOLD
# 308         IPHONE XS MAX      A12        4      256           WHITE
# 309         IPHONE XS MAX      A12        4      256           BLACK
# 191         IPHONE XS MAX      A12        4      512          SILVER
# 39          IPHONE XS MAX      A12        4       64          SILVER
# 40          IPHONE XS MAX      A12        4       64        JETBLACK
# 41          IPHONE XS MAX      A12        4       64            GOLD
# 167         IPHONE XS MAX      A12        4       64           BLACK
# 168         IPHONE XS MAX      A12        4       64           WHITE
# 382         IPHONE XS MAX  unknown  unknown      256            GRAY
# 381         IPHONE XS MAX  unknown  unknown       64            GRAY
