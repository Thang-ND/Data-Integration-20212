# %%
import pandas as pd

# %%
df = pd.read_json("../ddtm.json")
df.count
# df.count
# Out:
# <bound method DataFrame.count of                                  name  \
# 0      iPhone 11 64GB Chính Hãng VN/A
# 1      iPhone 11 64GB Chính Hãng VN/A
# 2      iPhone 11 64GB Chính Hãng VN/A
# 3      iPhone 11 64GB Chính Hãng VN/A
# 4      iPhone 11 64GB Chính Hãng VN/A
# ...                               ...
# 1579  iPhone 11 128GB Chính Hãng VN/A
# 1580  iPhone 11 128GB Chính Hãng VN/A
# 1581  iPhone 11 128GB Chính Hãng VN/A
# 1582  iPhone 11 128GB Chính Hãng VN/A
# 1583  iPhone 11 128GB Chính Hãng VN/A
#
#                                                     url  \
# 0             https://didongthongminh.vn/iphone-11-64gb
# 1             https://didongthongminh.vn/iphone-11-64gb
# 2             https://didongthongminh.vn/iphone-11-64gb
# 3             https://didongthongminh.vn/iphone-11-64gb
# 4             https://didongthongminh.vn/iphone-11-64gb
# ...                                                 ...
# 1579  https://didongthongminh.vn/iphone-11-128gb-chi...
# ...

# %%
df.head()
# Out:
#                                                 Name  \
# 0  Apple Watch SE 40mm (GPS) Viền Nhôm - Dây Cao ...
# 1  Apple Watch Series 6 44mm (4G) Viền Thép Dây C...
# 2  Apple Watch SE 44mm (GPS) Viền Nhôm - Dây Cao ...
# 3  Apple Watch SE 44mm (4G) Viền Nhôm - Dây Vải |...
# 4  Apple Watch SE 40mm (4G) Viền Nhôm - Dây Vải |...
#
#                           Price         ROM_P  \
# 0    [7.600.000 ₫, 6.890.000 ₫]  m, 40mm]
# 1  [14.590.000 ₫, 12.590.000 ₫]  m, 40mm]
# 2    [7.600.000 ₫, 6.890.000 ₫]  m, 40mm]
# 3    [7.490.000 ₫, 7.690.000 ₫]  m, 40mm]
# 4    [7.490.000 ₫, 7.690.000 ₫]  m, 40mm]
#
#                                                Color  \
# 0    ['Hồng', 'Tím', 'Trắng', 'Vàng', 'Xanh', 'Đen']
# 1                   ['Trắng', 'Vàng', 'Xanh', 'Đen']
# 2             ['Hồng', 'Trắng', 'Vàng/Trắng', 'Đen']
# 3  ['Vàng', 'Xám', 'Xám/Đen', 'Xanh', 'Xanh dương...
# 4               ['Nâu', 'Vàng', 'Xám', 'Xanh', 'Đỏ']
#
# ...

# %%
df[['Price_color', 'Color']]
# Out:
#                                           Price_color  \
# 0   ['6.890.000\xa0₫', '6.890.000\xa0₫', '6.890.00...
# 1   ['16.590.000\xa0₫', '14.590.000\xa0₫', '16.590...
# 2   ['7.900.000\xa0₫', '7.900.000\xa0₫', '7.500.00...
# 3   ['7.900.000\xa0₫', '7.590.000\xa0₫', '7.900.00...
# 4   ['7.690.000\xa0₫', '7.690.000\xa0₫', '7.690.00...
# 5                                  ['8.990.000\xa0₫']
# 6   ['8.500.000\xa0₫', '9.600.000\xa0₫', '9.000.00...
# 7   ['12.590.000\xa0₫', '13.490.000\xa0₫', '12.590...
# 8                                                  []
# 9   ['16.000.000\xa0₫', '14.590.000\xa0₫', '16.000...
# 10  ['7.900.000\xa0₫', '7.900.000\xa0₫', '7.900.00...
# 11  ['9.990.000\xa0₫', '9.590.000\xa0₫', '9.390.00...
# 12  ['10.290.000\xa0₫', '10.990.000\xa0₫', '10.590...
# 13  ['12.990.000\xa0₫', '13.590.000\xa0₫', '13.590...
# 14  ['11.990.000\xa0₫', '11.990.000\xa0₫', '11.990...
#
#                                                 Color
# ...
