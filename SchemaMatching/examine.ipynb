# %%
import os
import pandas as pd
from strsimpy.levenshtein import Levenshtein
from strsimpy.normalized_levenshtein import NormalizedLevenshtein
from valentine import valentine_match, valentine_metrics
from valentine.algorithms import Coma, Cupid, DistributionBased, JaccardLevenMatcher, SimilarityFlooding

# %%
path = "../PreprocessingData/Dataprocess/iphone/viettablet.json"
path2 = './IntegratedData/target_data.json'
df1 = pd.read_json(path2)
df2 = pd.read_json(path)

# %%
df1.head(2)
# Out:
#         name                                        url  \
# 0  IPHONE 11  https://didongthongminh.vn/iphone-11-64gb
# 1  IPHONE 11  https://didongthongminh.vn/iphone-11-64gb
#
#                         cpu  os                gpu    ram   rom        price  \
# 0  Apple A13 Bionic 6 nhân  NaN  Apple GPU 4 nhân   4 GB   64GB  11.640.000đ
# 1  Apple A13 Bionic 6 nhân  NaN  Apple GPU 4 nhân   4 GB   64GB  11.640.000đ
#
#    connect screentype  ...    bluetooth  \
# 0      NaN   IPS LCD   ...  A2DP, v5.0
# 1      NaN   IPS LCD   ...  A2DP, v5.0
#
#                                                 wifi  \
# 0   Wi-Fi hotspot Wi-Fi 802.11 a/b/g/n/ac/ax Dual...
# 1   Wi-Fi hotspot Wi-Fi 802.11 a/b/g/n/ac/ax Dual...
#
#                        size          resolution  \
# 0  6.1 - Tần số quét 60 Hz   828 x 1792 Pixels
# 1  6.1 - Tần số quét 60 Hz   828 x 1792 Pixels
#
#                                               weight  jack_audio  \
# ...

# %%
df2.head(2)
# Out:
#                                             Name         Price  \
# 0                                            NaN           NaN
# 1  iPhone 12 64GB Mới 100% fullbox Active Online  [13.390.000]
#
#                                                Color  \
# 0                                                NaN
# 1  [\n                                , \n       ...
#
#                                                 Data  \
# 0                                                NaN
# 1  [iOS 14, Apple A14 Bionic (5 nm), Kính oleopho...
#
#                                                 link Model-split Rom-split  \
# 0                                                NaN         NaN       NaN
# 1  https://www.viettablet.com/iphone-12-64gb-chin...   IPHONE 12      64GB
#
#   Status-split      OS                      CPU  ... mobile network  \
# 0          NaN     NaN                      NaN  ...            NaN
# 1         100%  iOS 14  Apple A14 Bionic (5 nm)  ...      Hỗ trợ 5G
#
# ...

# %%
matcher = Coma(strategy='COMA_OPT_INST')
matches = valentine_match(df1, df2, matcher)
print(matches)
# Out:
# {(('table_1', 'resolution'), ('table_2', 'resolution')): 0.9002736, (('table_1', 'security'), ('table_2', 'security')): 0.89654243, (('table_1', 'ram'), ('table_2', 'ram')): 0.88466704, (('table_1', 'sim'), ('table_2', 'sim')): 0.84456885, (('table_1', 'cpu'), ('table_2', 'CPU')): 0.8343484, (('table_1', 'mobile_network'), ('table_2', 'mobile network')): 0.81128013, (('table_1', 'name'), ('table_2', 'Name')): 0.8073203, (('table_1', 'color'), ('table_2', 'Color')): 0.7856591, (('table_1', 'material'), ('table_2', 'material')): 0.70350903, (('table_1', 'price'), ('table_2', 'Price')): 0.7012868, (('table_1', 'os'), ('table_2', 'OS')): 0.69850904, (('table_1', 'wifi'), ('table_2', 'wi-fi')): 0.65274787, (('table_1', 'rom'), ('table_2', 'Rom-split')): 0.6157918, (('table_1', 'screentype'), ('table_2', 'screen technology')): 0.6045383, (('table_1', 'size'), ('table_2', 'size screen')): 0.49674425, (('table_1', 'url'), ('table_2', 'link')): 0.43341985, (('table_1', 'jack_audio'), ('table_
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1584 entries, 0 to 1583
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1584 non-null   object
#  1   url               1584 non-null   object
#  2   cpu               1283 non-null   object
#  3   os                0 non-null      float64
#  4   gpu               1400 non-null   object
#  5   ram               1328 non-null   object
#  6   rom               1572 non-null   object
#  7   price             1584 non-null   object
#  8   connect           0 non-null      float64
#  9   screentype        1418 non-null   object
#  10  color             1584 non-null   object
#  11  front_camera      0 non-null      float64
#  12  rear_camera       0 non-null      float64
#  13  battery_capacity  1418 non-null   object
#  14  bluetooth         1418 non-null   object
#  15  wifi              1418 non-null   object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                150 non-null    object
#  1   Price               150 non-null    object
#  2   Color               150 non-null    object
#  3   Data                150 non-null    object
#  4   link                150 non-null    object
#  5   Model-split         145 non-null    object
#  6   Rom-split           143 non-null    object
#  7   Status-split        76 non-null     object
#  8   OS                  143 non-null    object
#  9   CPU                 143 non-null    object
#  10  resolution          143 non-null    object
#  11  screen technology   141 non-null    object
#  12  size screen         85 non-null     object
#  13  mobile network      135 non-null    object
#  14  charging port       140 non-null    object
# ...
