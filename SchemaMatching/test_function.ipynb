# %%
import os
import pandas as pd
from strsimpy.levenshtein import Levenshtein
from strsimpy.normalized_levenshtein import NormalizedLevenshtein
from valentine import valentine_match, valentine_metrics
from valentine.algorithms import Coma, Cupid, DistributionBased, JaccardLevenMatcher, SimilarityFlooding
from SchemaMatchingSystem import SchemaMatchingSystem

# %%
smSystem = SchemaMatchingSystem()
path = "../PreprocessingData/Dataprocess/iphone/xtmobile.json"
df = pd.read_json(path)

# %%
df2 = df.drop(["Kiểu màn hình"], axis=1)
columns = list(df2.columns)

# %%
res = smSystem.schema_matching(columns, threshold=0.85)
res

# %%
def matchedCol(result): 
    matched_col = []
    source_col = []
    for key in result:
        matched_col.append(result[key])
        source_col.append(key)
    
    return matched_col, source_col

# %%
matched_col, source_col = matchedCol(res)

# %%
df_tmp = df2[source_col].rename(columns=res)

# %%
data = pd.DataFrame(columns=smSystem.getTargetSchema())

# %%
data[matched_col] = df_tmp[matched_col]

# %%
data
# Out:
#                                                   name  ...                                           material
# 0    iPhone 12 64GB (LikeNew 99,99% - FullBox) - Pi...  ...      Khung nhôm + Màn hình mặt gốm + Mặt lưng kính
# 1    iPhone 12 64GB (LikeNew 99,99% - FullBox) - Pi...  ...      Khung nhôm + Màn hình mặt gốm + Mặt lưng kính
# 2    iPhone 12 64GB (LikeNew 99,99% - FullBox) - Pi...  ...      Khung nhôm + Màn hình mặt gốm + Mặt lưng kính
# 3    iPhone 12 64GB (LikeNew 99,99% - FullBox) - Pi...  ...      Khung nhôm + Màn hình mặt gốm + Mặt lưng kính
# 4    iPhone 12 64GB (LikeNew 99,99% - FullBox) - Pi...  ...      Khung nhôm + Màn hình mặt gốm + Mặt lưng kính
# ..                                                 ...  ...                                                ...
# 324             iPhone SE 2022 128GB Chính hãng (VN/A)  ...
# 325             iPhone SE 2022 256GB Chính hãng (VN/A)  ...
# 326             iPhone SE 2022 256GB Chính hãng (VN/A)  ...
# 327             iPhone SE 2022 256GB Chính hãng (VN/A)  ...
# 328            iPhone 13 Pro Max 256GB (Cũ 99%) (VN/A)  ...  Khung thép không gỉ &amp; Mặt lưng kính cường lực
#
# [329 rows x 24 columns]
